# %%
# !git clone https://github.com/unreal-kz/lab-01-AI-course
# %cd /content/lab-01-AI-course
# !pip install -q tiktoken google-genai
# Out:
# Cloning into 'lab-01-AI-course'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 25 (delta 8), reused 21 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 25.13 KiB | 6.28 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/lab-01-AI-course

# %%
# !python part0_tokenizers.py
# Out:
# PART 0 -- OpenAI tokenizer pair. No API key, no cost, no network.
#
# SENTENCE
# ------------------------------------------------------------------
#                          EN           RU           KK
# o200k_base               12           18           21
#   ÷ EN                1.00x        1.50x        1.75x
# cl100k_base              12           35           58
#   ÷ EN                1.00x        2.92x        4.83x
#
# COMPLAINT
# ------------------------------------------------------------------
#                          EN           RU           KK
# o200k_base               59           80          118
#   ÷ EN                1.00x        1.36x        2.00x
# cl100k_base              59          146          265
#   ÷ EN                1.00x        2.47x        4.49x
#
# SYSTEM_PROMPT
# ------------------------------------------------------------------
#                          EN           RU           KK
# o200k_base               40           49           67
# ...

# %%
# !python part1_offline.py
# Out:
# PART 1 -- offline size measures. No API key, no cost, no network.
#
# SENTENCE
# ------------------------------------------------------------------
#                          EN           RU           KK
# chars                    69           75           72
# bytes                    69          139          135
# words                    11           11            9
# bytes/EN              1.00x        2.01x        1.96x
# bytes/char             1.00         1.85         1.88
#
# COMPLAINT
# ------------------------------------------------------------------
#                          EN           RU           KK
# chars                   300          315          344
# bytes                   300          576          640
# words                    54           45           42
# bytes/EN              1.00x        1.92x        2.13x
# bytes/char             1.00         1.83         1.86
#
# SYSTEM_PROMPT
# ------------------------------------------------------------------
# ...

# %%
import os
from google.colab import userdata
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
# !python part2_measure.py
# Out:
# counting tokens on gemini-3-flash-preview (free, no model run)
#   sentence       en=13  ru=18  kk=31
#   complaint      en=60  ru=79  kk=149
#   system_prompt  en=41  ru=52  kk=88
#   request        en=101  ru=131  kk=237  (system + complaint -- what Part 3 prices)
#
# wrote measurements.json

# %%
# !python part2_measure.py --call
# Out:
# counting tokens on gemini-3-flash-preview (free, no model run)
#   sentence       en=13  ru=18  kk=31
#   complaint      en=60  ru=79  kk=149
#   system_prompt  en=41  ru=52  kk=88
#   request        en=101  ru=131  kk=237  (system + complaint -- what Part 3 prices)
#
# answering the same complaint on gemini-3-flash-preview, in each language:
#
# [en]
#   finish_reason: FinishReason.STOP
#   --- answer ---
#   I am sorry, but the contract and statement you mentioned were not provided. As the information is not in the documents available to me, I cannot explain the basis for the rate change or restore the original terms. Please provide the documents so I can assist you further.
#   billed: 101 in, 1211 out (53 visible + 1158 thinking)
#
# [ru]
#   finish_reason: FinishReason.STOP
#   --- answer ---
#   Здравствуйте. К сожалению, в вашем обращении отсутствует текст договора и выписки, на которые вы ссылаетесь.
#
# ...

# %%
# !python part3_cost.py
# !python part3_cost.py --requests-per-day 5000
# Out:
# prices from https://ai.google.dev/gemini-api/docs/pricing
# checked 2026-09-20; tokens counted on gemini-3-flash-preview
# answer length: measured in Part 2, per language
#
# ONE SUPPORT REQUEST -- tokens, and cost in US cents
# ------------------------------------------------------------------------
#                         EN          RU          KK
# input tokens           101         131         237
# output tokens         1211         865        1178
# flash-lite-3.1      0.1842      0.1330      0.1826
# flash-3             0.3684      0.2661      0.3653
# pro-3.1             1.4734      1.0642      1.4610
#
# AT 2,000 REQUESTS/DAY -- US dollars per year
# ------------------------------------------------------------------------
#                         EN          RU          KK
# flash-lite-3.1       1,344         971       1,333
# flash-3              2,689       1,942       2,666
# pro-3.1             10,756       7,769      10,665
#
# ...
